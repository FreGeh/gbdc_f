# %% [markdown]
# **Installing basic libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Getting results**

# %%
limit_run = 49379
unlimited_run = 49265

file_limit = f"results/{limit_run}.tsv"
file_unlimit = f"results/{unlimited_run}.tsv"

df_limit = pd.read_csv(file_limit, sep='\t', header=0)
df_unlimit = pd.read_csv(file_unlimit, sep='\t', header=0)

# %% [markdown]
# **Max Iteration Limit Config**
# - raw results
# - data gathering
# - plots

# %%
df_limit.head()

# %%
df_unlimit.head()
